# %%
m_wheel = 2.9
m_body = 4
m_rod = 1.4

r_wheel = 0.085

l_rod = 1.6

com = (m_rod * l_rod / 2) / (m_body + m_rod)
# com_without_wheels = (m_rod * l_rod / 2) / (m_body + m_rod)

m_rod_lower = m_rod * (com / l_rod)
m_rod_upper = m_rod * (1 - com / l_rod)

Jb = (m_body) * com + 1/3 * (m_rod_lower * com**2 + m_rod_upper * (l_rod - com)**2 )
Jw = 1/2 * (2 * m_wheel) * r_wheel**2
print("Jb", Jb)
print("Jw", Jw)
print("com", com)
print("M", m_body + m_rod)
# print("com without wheel", com_without_wheels)
# Out:
# Jb 1.6199286694101511
# Jw 0.020952500000000002
# com 0.20740740740740737
# M 5.4

# %%
m_wheel = 2.9
m_body = 4
m_rod = 1.4

r_wheel = 0.085

l_rod = 1.6

com = (m_rod * l_rod / 2) / (m_body + m_rod)
# com_without_wheels = (m_rod * l_rod / 2) / (m_body + m_rod)

m_rod_lower = m_rod * (com / l_rod)
m_rod_upper = m_rod * (1 - com / l_rod)

Jb = (m_body) * com + 1/3 * (m_rod_lower * com**2 + m_rod_upper * (l_rod - com)**2 )
Jw = 1/2 * (2 * m_wheel) * r_wheel**2
print("Jb", Jb)
print("Jw", Jw)
print("com", com)
print("M", m_body + m_rod)
# print("com without wheel", com_without_wheels)
# Out:
# Jb 1.6199286694101511
# Jw 0.020952500000000002
# com 0.20740740740740737
# M 5.4

# %%
m_wheel = 2.9
m_body = 4
m_rod = 0

r_wheel = 0.085

l_rod = 1.6

com = (m_rod * l_rod / 2) / (m_body + m_rod + m_wheel)
# com_without_wheels = (m_rod * l_rod / 2) / (m_body + m_rod)

m_rod_lower = m_rod * (com / l_rod)
m_rod_upper = m_rod * (1 - com / l_rod)

Jb = (m_body + m_wheel) * com + 1/3 * (m_rod_lower * com**2 + m_rod_upper * (l_rod - com)**2 )
Jw = 1/2 * (2 * m_wheel) * r_wheel**2
print("Jb", Jb)
print("Jw", Jw)
print("com", com)
print("M", m_body + m_rod)
# print("com without wheel", com_without_wheels)
# Out:
# Jb 0.0
# Jw 0.020952500000000002
# com 0.0
# M 4
